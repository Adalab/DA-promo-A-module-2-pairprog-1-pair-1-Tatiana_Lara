# %% [markdown]
# # 25/04 - Pair Programming Visualización 1 - Tatiana & Lara

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
df = pd.read_csv("datos_guardados.csv")
df.head()
# Out:
#    Unnamed: 0  unnamed:_0 case_number    year        type    country  \
# 0           0           0  2018.06.25  2018.0     Boating        USA
# 1           1           1  2018.06.18  2018.0  Unprovoked        USA
# 2           2           2  2018.06.09  2018.0     Invalid        USA
# 3           3           3  2018.06.08  2018.0  Unprovoked  AUSTRALIA
# 4           4           4  2018.06.04  2018.0    Provoked     MEXICO
#
#               area                        location     activity  \
# 0       California     Oceanside, San Diego County     Paddling
# 1          Georgia  St. Simon Island, Glynn County     Standing
# 2           Hawaii                    Habush, Oahu      Surfing
# 3  New South Wales              Arrawarra Headland      Surfing
# 4           Colima                        La Ticla  Free diving
#
#                name sex_  age           time         species_  \
# 0       Julie Wolfe    F   57          18h00      White shark
# 1  AdysonÂ McNeely     F   11  14h00  -15h00              NaN
# 2       John Denges    M   48          07h45              NaN
# 3              male    M  NaN            NaN        2 m shark
# 4    Gustavo Ramos     M  NaN            NaN  Tiger shark, 3m
#
#                                                 href
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# # Ejercicio 1
# ¿Cuál es la frecuencia de cada una de las categorías de la columna sex?

# %%
# Valores únicos, contarlos, hacer una gráfica que muestre la frecuencia de M / F / otros
freq = df["sex_"].value_counts()
print(freq)

plt.figure()
x= "M","F","M","N","lli","."
y= 4939,619,2,2,1,1

plt.bar(x,y)
plt.show()
# Out:
# M      4939
# F       619
# M         2
# N         2
# lli       1
# .         1
# Name: sex_, dtype: int64

# %% [markdown]
# # Ejercicio 2
# ¿Cuál es el porcentaje de nulos por columna? Usa un pie chart donde incluyáis el porcentaje de cada variable en el interior del quesito. Para eso tendréis que usar el parámetro autopct, aquí algo de documentación.

# %%
nulos = df.isnull().sum()
total = df.shape[0]
porc = nulos / total * 100

plt.figure()

plt.pie(porc, labels = porc, autopct='%1.2f%%')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# # Ejercicio 3
# ¿Cuál es número total de valores únicos de cada una de las columnas categóricas del dataframe?

# %%
df.groupby('case_number')['unnamed:_0'].unique
#df['case_number', 'unnamed:_0', 'year', 'type', 'country', 'area','location', 'activity', 'name', 'sex_', 'age', 'time', 'species_','href'].value_counts()
#columnas = 'case_number', 'unnamed:_0', 'year', 'type', 'country', 'area','location', 'activity', 'name', 'sex_', 'age', 'time', 'species_','href'
#for columna in columnas:
   # df[columnas].unique()
# Out:
# case_number   unnamed:_0
# 1801.12.18.R  6131          1
# 1802.04.13.R  6130          1
# 1803.03.00    6129          1
# 1803.05.17    6128          1
# 1804.02.26.R  6127          1
#                            ..
# 2018.06.04    4             1
# 2018.06.08    3             1
# 2018.06.09    2             1
# 2018.06.18    1             1
# 2018.06.25    0             1
# Name: unnamed:_0, Length: 6113, dtype: int64

# %% [markdown]
# # Ejercicio 4
# Filtrad los datos para quedarnos solo con los datos de USA.
# ¿Cuántos ataques de tiburones hubo en USA a lo largo del tiempo? Muestra solo los que hayan ocurrido del 2000 en adelante.

# %%
USA = df[df["country"] == "USA"]
USA_2000 = df[(df["country"] == "USA") & (df["year"] >= 2000)]
USA_2000
#preguntar porque los años estan en float
# Out:
#       Unnamed: 0  unnamed:_0   case_number    year        type country  \
# 0              0           0    2018.06.25  2018.0     Boating     USA
# 1              1           1    2018.06.18  2018.0  Unprovoked     USA
# 2              2           2    2018.06.09  2018.0     Invalid     USA
# 7              7           7    2018.05.27  2018.0  Unprovoked     USA
# 8              8           8  2018.05.26.b  2018.0  Unprovoked     USA
# ...          ...         ...           ...     ...         ...     ...
# 2055        2055        2062    2000.03.26  2000.0  Unprovoked     USA
# 2056        2056        2063    2000.03.24  2000.0  Unprovoked     USA
# 2063        2063        2070    2000.03.00  2000.0  Unprovoked     USA
# 2064        2064        2071    2000.02.21  2000.0  Unprovoked     USA
# 2071        2071        2078    2000.00.00  2000.0        Boat     USA
#
#             area                                           location  \
# 0     California                        Oceanside, San Diego County
# 1        Georgia                     St. Simon Island, Glynn County
# 2         Hawaii                                       Habush, Oahu
# 7        Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
# 8        Florida                       Cocoa Beach, Brevard  County
# ...          ...                                                ...
# 2055     Florida                      Juno Beach, Palm Beach County
# 2056     Florida                    Floridana Beach, Brevard County
# 2063   Louisiana                  Midnight Lump (38 miles offshore)
# 2064     Florida                   Riviera Beach, Palm Beach County
# 2071     Florida                            Boca Grande, Lee County
#
#                 activity                           name sex_  age  \
# 0               Paddling                    Julie Wolfe    F   57
# 1               Standing               AdysonÂ McNeely     F   11
# 2                Surfing                    John Denges    M   48
# 7                Fishing                           male    M   52
# 8                Walking                      Cody High    M   15
# ...                  ...                            ...  ...  ...
# 2055     Boogie boarding               Heather Van Olst    F   14
# 2056             Surfing                 Barry Pasonski    M   37
# 2063        Spearfishing                    Kurt Bickel    M   39
# 2064                 NaN                           male    M   27
# 2071  Fishing for tarpon  boat: occupant, Terry Winters    M  NaN
#
#                time                                         species_  \
# 0             18h00                                      White shark
# 1     14h00  -15h00                                              NaN
# 2             07h45                                              NaN
# 7               NaN                                  Lemon shark, 3'
# 8             17h00                                   Bull shark, 6'
# ...             ...                                              ...
# 2055          11h15                                 1.8 m [6'] shark
# 2056          14h00                                 1.2 m [4'] shark
# 2063          16h00  Shortfin mako shark, 3 m to 3.4 m [10' to 11']
# 2064      Afternoon                                              NaN
# 2071            NaN                                 Hammerhead shark
#
#                                                    href
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...
# 7     http://sharkattackfile.net/spreadsheets/pdf_di...
# 8     http://sharkattackfile.net/spreadsheets/pdf_di...
# ...                                                 ...
# 2055  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2056  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2063  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2064  http://sharkattackfile.net/spreadsheets/pdf_di...
# 2071  http://sharkattackfile.net/spreadsheets/pdf_di...
#
# [1011 rows x 15 columns]

# %% [markdown]
# En función del tipo, ¿cuántos ataques de cada tipo de tiburones hubo en USA? Muestra los resultados en un gráfico de línea.

# %%
usa_types = USA["species_"].value_counts()
print(usa_types)
#plt.figure()

#x = USA["species_"].unique()
#y = USA["species_"].value_counts().tolist()

#plt.plot(x, y)
#plt.show()
# Out:
# Shark involvement not confirmed                       53
# White shark                                           43
# 4' shark                                              38
# Invalid                                               31
# Shark involvement prior to death was not confirmed    30
#                                                       ..
# Questionable Incident                                  1
# Mako shark, 1.8 m [6']                                 1
# 2.4 m to 3.7 m [8' to 12'] shark                       1
# 9'2" white shark                                       1
# Said to be a 7.6 m [25'] shark                         1
# Name: species_, Length: 635, dtype: int64

# %% [markdown]
# # Ejercicio 5
# ¿Cuántos ataques de tiburones hubo en España a lo largo del tiempo? Muestra solo los que hayan ocurrido del 2000 en adelante.

# %%
spain = df[df["country"] == "SPAIN"]
spain
# Out:
# Series([], Name: year, dtype: int64)

# %%
spain2000 = df[(df["country"] == "SPAIN") & (df["year"] >= 2000)]
spain2000.head(2)
# Out:
#     Unnamed: 0  unnamed:_0   case_number    year        type country  \
# 82          82          82  2017.09.16.b  2017.0  Unprovoked   SPAIN
# 98          98          98  2017.08.26.b  2017.0     Invalid   SPAIN
#
#               area         location      activity    name sex_ age    time  \
# 82  Canary Islands    Gran Canaria   Body surfing    male    M  13     NaN
# 98      CastellÃ³n  Grao de Moncofa      Swimming  female    F  11  Midday
#
#                           species_  \
# 82                Porbeagle, 1.5 m
# 98  Shark involvement questionable
#
#                                                  href
# 82  http://sharkattackfile.net/spreadsheets/pdf_di...
# 98  http://sharkattackfile.net/spreadsheets/pdf_di...

# %% [markdown]
# En función del tipo, ¿cuántos ataques de cada tipo de tiburones hubo en España? Muestra los resultados en un gráfico de línea.

# %%
spain_types = spain["species_"].value_counts()
spain_types
# Out:
# Blue shark                                                                    3
# Angel shark                                                                   3
# 16' shark                                                                     2
# Shark involvement prior to death unconfirmed                                  2
# Shark involvement not confirmed                                               2
# Shark involvement questionable                                                2
# Porbeagle, 1.5 m                                                              1
# Questionable, 2m shark suspected                                              1
# 2.5 m shark                                                                   1
# Questionable                                                                  1
# White shark                                                                   1
# 3.5 m shark                                                                   1
# 2 m shark                                                                     1
# 3.5 m white shark                                                             1
# 1.2 m [4'] shark                                                              1
# Shark involvement not confirmed, injury may have been caused by a bluefish    1
# small shark                                                                   1
# Silky shark, 6.5'                                                             1
# Blue shark 6'                                                                 1
# Invalid                                                                       1
# Name: species_, dtype: int64
